# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Load the data from file and save train/test data

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('extracted_data.csv')
df = df.dropna(axis=1)
df = df.replace([np.inf, -np.inf], np.nan).dropna(axis=1)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

df.head()
# Out:
#    Flow rate_Time_standard_error_mean  Flow rate_Time_signal_energy  \
# 0                        2.012151e-07                  1.121846e-09
# 1                        2.373305e-07                  1.128794e-09
# 2                        2.117180e-07                  1.990315e-09
# 3                        2.112434e-07                  2.159600e-09
# 4                        1.877035e-07                  1.281446e-09
#
#    Flow rate_Time_maximum  Flow rate_Time_minimum  Flow rate_Time_skewness  \
# 0                0.000008            7.385040e-15                -0.015488
# 1                0.000008            2.983600e-31                 1.402138
# 2                0.000008            7.662260e-70                 0.239625
# 3                0.000007            1.386020e-65                -0.004838
# 4                0.000008            8.178460e-80                 0.409115
#
#    Flow rate_Time_kurtosis  Flow rate_Time_standard_deviation  \
# 0                -0.882549                           0.000002
# 1                 0.113374                           0.000003
# 2                -1.605099                           0.000003
# 3                -1.931155                           0.000003
# 4                -0.739532                           0.000002
#
#    Flow rate_Time_variance  Flow rate_Time_length  Flow rate_Time_mean  \
# 0             3.603388e-12                     90             0.000003
# 1             6.871743e-12                    123             0.000002
# 2             6.813326e-12                    153             0.000002
# 3             6.827436e-12                    154             0.000003
# 4             4.721168e-12                    135             0.000002
#
#     ...    Constant_Values_Zone30_K1  Constant_Values_Zone30_K2  \
# 0   ...                 4.000000e-11               5.000000e-11
# 1   ...                 4.000000e-11               5.000000e-11
# 2   ...                 4.000000e-11               5.000000e-11
# 3   ...                 4.000000e-11               5.000000e-11
# 4   ...                 4.000000e-11               5.000000e-11
#
#    Constant_Values_Zone30_K3  Constant_Values_Zone30_tfilling  \
# 0               2.000000e-12                          5.08464
# 1               2.000000e-12                          5.17018
# 2               2.000000e-12                          5.14247
# 3               2.000000e-12                          4.54960
# 4               2.000000e-12                          5.08549
#
#    Constant_Values_Zone_ids.27  Constant_Values_Zone31_K1  \
# 0                         31.0               4.000000e-11
# 1                         31.0               4.000000e-11
# 2                         31.0               4.000000e-11
# 3                         31.0               4.000000e-11
# 4                         31.0               4.000000e-11
#
#    Constant_Values_Zone31_K2  Constant_Values_Zone31_K3  \
# 0               5.000000e-11               2.000000e-12
# 1               5.000000e-11               2.000000e-12
# 2               5.000000e-11               2.000000e-12
# 3               5.000000e-11               2.000000e-12
# 4               5.000000e-11               2.000000e-12
#
#    Constant_Values_Zone31_tfilling  target
# 0                          7.14719       1
# 1                          7.22421       1
# 2                          7.26887       1
# 3                          6.32605       1
# 4                          6.76541       1
#
# [5 rows x 3894 columns]

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
y.value_counts()
# Out:
# 1    5049
# 0    4951
# Name: target, dtype: int64

# %% [markdown]
# ### Automatic sccoring function

# %%
#code
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import roc_auc_score, f1_score

seed = 0

def automatic_scoring_cv(X, y):
    rf_model = RandomForestClassifier(n_estimators=100, random_state=seed)
    average_score = cross_val_score(estimator=rf_model, X=X, y=y, cv=5, scoring='roc_auc', n_jobs=-1).mean()
    return 'cv + roc_auc: ' + str(average_score)

def automatic_scoring_tt(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=seed, stratify=y)
    rf_model = RandomForestClassifier(n_estimators=100, random_state=seed).fit(X_train, y_train)
    y_pred = rf_model.predict(X_test)
    return 'tt + f1_score: ' + str(f1_score(y_test, y_pred))

# %%
automatic_scoring_cv(X, y)
# Out:
# 'cv + roc_auc: 0.8879755236404773'

# %% [markdown]
# ### 1. Feature selector that removes all low-variance features.

# %%
#code
from sklearn.feature_selection import VarianceThreshold

selector = VarianceThreshold(threshold=(.8 * (1 - .8)))
selector.fit(X)
columns = X.columns[selector.get_support(indices=True)]
X = X[columns]

X.head()
# Out:
#    Flow rate_Time_skewness  Flow rate_Time_kurtosis  Flow rate_Time_length  \
# 0                -0.015488                -0.882549                     90
# 1                 1.402138                 0.113374                    123
# 2                 0.239625                -1.605099                    153
# 3                -0.004838                -1.931155                    154
# 4                 0.409115                -0.739532                    135
#
#    Flow rate_Time_cid_ce  Flow rate_Time_sample_entropy  \
# 0               2.338973                       1.923687
# 1               1.562565                       0.553437
# 2               2.938788                       0.967050
# 3               1.703203                       0.925972
# 4               3.353975                       0.974327
#
#    Flow rate_Time_augmented_dickey_fuller_teststat  \
# 0                                        -2.038672
# 1                                        -2.371455
# 2                                        -2.120462
# 3                                        -1.170086
# 4                                        -0.588509
#
#    Flow rate_Time_augmented_dickey_fuller_usedlag  \
# 0                                               1
# 1                                               4
# 2                                               0
# 3                                               0
# 4                                               5
#
#    Flow rate_Time_large_standard_deviation_0.1  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
#
#    Flow rate_Time_large_standard_deviation_0.15000000000000002  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Flow rate_Time_large_standard_deviation_0.2  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
#
#                 ...                 Constant_Values_Zone9_tfilling  \
# 0               ...                                        8.71076
# 1               ...                                        9.01861
# 2               ...                                        8.20194
# 3               ...                                        9.47419
# 4               ...                                        9.34483
#
#    Constant_Values_Zone10_tfilling  Constant_Values_Zone15_tfilling  \
# 0                          5.32217                          5.40678
# 1                          5.30301                          4.95850
# 2                          4.84727                          5.44917
# 3                          5.71240                          4.83943
# 4                          5.48449                          4.97950
#
#    Constant_Values_Zone16_tfilling  Constant_Values_Zone17_tfilling  \
# 0                          9.05436                          8.91207
# 1                          8.58738                          9.03714
# 2                          9.15164                          8.58509
# 3                          8.25596                          9.39794
# 4                          8.77925                          9.38939
#
#    Constant_Values_Zone18_tfilling  Constant_Values_Zone23_tfilling  \
# 0                          5.37182                          5.37182
# 1                          5.41979                          5.35064
# 2                          1.57392                          5.41989
# 3                          5.74066                          4.96893
# 4                          5.59861                          5.52508
#
#    Constant_Values_Zone24_tfilling  Constant_Values_Zone26_tfilling  \
# 0                          8.97084                          7.14719
# 1                          8.81792                          7.03890
# 2                          9.09192                          6.83842
# 3                          8.13939                          7.23515
# 4                          8.83900                          7.33478
#
#    Constant_Values_Zone31_tfilling
# 0                          7.14719
# 1                          7.22421
# 2                          7.26887
# 3                          6.32605
# 4                          6.76541
#
# [5 rows x 3071 columns]

# %%
automatic_scoring_cv(X, y)
# Out:
# 'cv + roc_auc: 0.8852018839298559'

# %% [markdown]
# ### 2. Feature selector that checks correlation between 2 features. If correlation is high, 1 feature is removed.

# %%
#code
import numpy as np

def correl(data, threshold):
    corr = data.corr()
    print('Corr calculated')
    columns = np.full((corr.shape[0],), True, dtype=bool)
    for i in range(corr.shape[0]):
        for j in range(i+1, corr.shape[0]):
            if corr.iloc[i,j] >= threshold:
                if columns[j]:
                    columns[j] = False
    selected_columns = data.columns[columns]
    data = data[selected_columns]
    return data

X = correl(X, 0.9)

X.head()
# Out:
# Corr calculated
#    Flow rate_Time_skewness  Flow rate_Time_length  \
# 0                -0.015488                     90
# 1                 1.402138                    123
# 2                 0.239625                    153
# 3                -0.004838                    154
# 4                 0.409115                    135
#
#    Flow rate_Time_sample_entropy  \
# 0                       1.923687
# 1                       0.553437
# 2                       0.967050
# 3                       0.925972
# 4                       0.974327
#
#    Flow rate_Time_augmented_dickey_fuller_teststat  \
# 0                                        -2.038672
# 1                                        -2.371455
# 2                                        -2.120462
# 3                                        -1.170086
# 4                                        -0.588509
#
#    Flow rate_Time_augmented_dickey_fuller_usedlag  \
# 0                                               1
# 1                                               4
# 2                                               0
# 3                                               0
# 4                                               5
#
#    Flow rate_Time_large_standard_deviation_0.1  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
#
#    Flow rate_Time_large_standard_deviation_0.15000000000000002  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Flow rate_Time_large_standard_deviation_0.2  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
#
#    Flow rate_Time_large_standard_deviation_0.25  \
# 0                                         False
# 1                                          True
# 2                                          True
# 3                                          True
# 4                                          True
#
#    Flow rate_Time_large_standard_deviation_0.30000000000000004  \
# 0                                              False
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                              False
#
#                 ...                 Constant_Values_Zone9_tfilling  \
# 0               ...                                        8.71076
# 1               ...                                        9.01861
# 2               ...                                        8.20194
# 3               ...                                        9.47419
# 4               ...                                        9.34483
#
#    Constant_Values_Zone10_tfilling  Constant_Values_Zone15_tfilling  \
# 0                          5.32217                          5.40678
# 1                          5.30301                          4.95850
# 2                          4.84727                          5.44917
# 3                          5.71240                          4.83943
# 4                          5.48449                          4.97950
#
#    Constant_Values_Zone16_tfilling  Constant_Values_Zone17_tfilling  \
# 0                          9.05436                          8.91207
# 1                          8.58738                          9.03714
# 2                          9.15164                          8.58509
# 3                          8.25596                          9.39794
# 4                          8.77925                          9.38939
#
#    Constant_Values_Zone18_tfilling  Constant_Values_Zone23_tfilling  \
# 0                          5.37182                          5.37182
# 1                          5.41979                          5.35064
# 2                          1.57392                          5.41989
# 3                          5.74066                          4.96893
# 4                          5.59861                          5.52508
#
#    Constant_Values_Zone24_tfilling  Constant_Values_Zone26_tfilling  \
# 0                          8.97084                          7.14719
# 1                          8.81792                          7.03890
# 2                          9.09192                          6.83842
# 3                          8.13939                          7.23515
# 4                          8.83900                          7.33478
#
#    Constant_Values_Zone31_tfilling
# 0                          7.14719
# 1                          7.22421
# 2                          7.26887
# 3                          6.32605
# 4                          6.76541
#
# [5 rows x 234 columns]

# %%
automatic_scoring_cv(X, y)
# Out:
# 'cv + roc_auc: 0.9070809713810641'

# %% [markdown]
# ### 3. Select features according to a percentile of the highest scores (mutual_info_classif)

# %%
from sklearn.feature_selection import SelectPercentile, mutual_info_classif

selperc = SelectPercentile(mutual_info_classif, percentile=10)
X_features = selperc.fit_transform(X, y)
columns = np.asarray(X.columns.values)
support = np.asarray(selperc.get_support())
columns_with_support = columns[support]

X = X[columns_with_support]
X.head()
# Out:
#    Flow rate_Time_skewness  Flow rate_Time_sample_entropy  \
# 0                -0.015488                       1.923687
# 1                 1.402138                       0.553437
# 2                 0.239625                       0.967050
# 3                -0.004838                       0.925972
# 4                 0.409115                       0.974327
#
#    Flow rate_Time_large_standard_deviation_0.1  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
#
#    Flow rate_Time_large_standard_deviation_0.15000000000000002  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    Flow rate_Frequency_signal_energy  Flow rate_Frequency_skewness  \
# 0                       1.929465e-07                      6.022285
# 1                       1.754497e-07                      3.987482
# 2                       3.511431e-07                      6.220548
# 3                       3.876618e-07                      6.390315
# 4                       2.228542e-07                      6.012997
#
#    Zone7_Pressure_Time_cid_ce  Zone9_Pressure_Time_median  \
# 0                    2.559244                    63948.20
# 1                    1.929611                    55132.90
# 2                    4.163208                    53513.20
# 3                    2.331688                    16559.45
# 4                    3.785949                    13740.30
#
#    Zone9_Pressure_Time_percentile_95  \
# 0                          74837.140
# 1                          59955.070
# 2                          96443.460
# 3                          58867.045
# 4                          65015.820
#
#    Zone15_Pressure_Time_augmented_dickey_fuller_teststat  \
# 0                                          -0.255487
# 1                                          -2.090178
# 2                                          -3.147783
# 3                                          -1.355158
# 4                                          -2.734639
#
#                 ...                 Zone18_Pressure_Time_median  \
# 0               ...                                     62204.0
# 1               ...                                     45323.0
# 2               ...                                     40277.4
# 3               ...                                     46045.6
# 4               ...                                     45465.6
#
#    Zone23_Pressure_Time_augmented_dickey_fuller_teststat  \
# 0                                          -1.924673
# 1                                          -2.106598
# 2                                          -3.154167
# 3                                          -1.316847
# 4                                          -2.657794
#
#    Zone23_Pressure_Time_augmented_dickey_fuller_usedlag  \
# 0                                                  1
# 1                                                  4
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Zone24_Pressure_Time_kurtosis  Zone24_Pressure_Time_sample_entropy  \
# 0                      -0.573096                             2.047256
# 1                       0.582974                             1.766882
# 2                      -1.383036                             1.588840
# 3                      -0.863062                             1.415317
# 4                      -0.113447                             1.469364
#
#    Zone24_Pressure_Time_augmented_dickey_fuller_usedlag  \
# 0                                                  4
# 1                                                  4
# 2                                                  1
# 3                                                  1
# 4                                                  5
#
#    Zone24_Pressure_Frequency_skewness  \
# 0                            6.631168
# 1                            5.913858
# 2                            6.875512
# 3                            6.412217
# 4                            7.730912
#
#    Zone30_Pressure_Time_augmented_dickey_fuller_teststat  \
# 0                                          -1.757511
# 1                                          -2.218144
# 2                                          -2.523897
# 3                                          -1.276491
# 4                                          -2.678957
#
#    Constant_Values_Zone16_tfilling  Constant_Values_Zone24_tfilling
# 0                          9.05436                          8.97084
# 1                          8.58738                          8.81792
# 2                          9.15164                          9.09192
# 3                          8.25596                          8.13939
# 4                          8.77925                          8.83900
#
# [5 rows x 24 columns]

# %%
automatic_scoring_cv(X, y)
# Out:
# 'cv + roc_auc: 0.8959568083739656'

# %%
X['target'] = y
X.to_csv('selected_data.csv')
