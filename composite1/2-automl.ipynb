# %% [markdown]
# # Composite AutoML

# %%
import numpy as np
import pandas as pd

seed = 0

df = pd.read_csv('tmp/selected_data.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

X = df.iloc[:,:-1]
y = df.iloc[:,-1]

df.head()
# Out:
#    Flow rate__fft_aggregated__aggtype_"centroid"  \
# 0                                      49.084752
# 1                                      51.389448
# 2                                      32.345881
# 3                                      46.956311
# 4                                      45.288313
#
#    Flow rate__fft_coefficient__coeff_1__attr_"angle"  \
# 0                                        -120.106950
# 1                                        -110.924886
# 2                                        -156.802057
# 3                                        -136.572893
# 4                                        -138.038339
#
#    Zone10_Pressure__fft_coefficient__coeff_2__attr_"real"  \
# 0                                      -7.922041e+04
# 1                                       8.590550e+05
# 2                                      -1.078723e+06
# 3                                       3.193206e+05
# 4                                      -1.226468e+06
#
#    Zone11_Pressure__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4  \
# 0                                         148.990311
# 1                                         159.261794
# 2                                          60.594163
# 3                                          97.424653
# 4                                          73.602326
#
#    Zone11_Pressure__fft_aggregated__aggtype_"centroid"  \
# 0                                          50.917722
# 1                                          61.470542
# 2                                          44.667697
# 3                                          58.688364
# 4                                          52.136797
#
#    Zone14_Pressure__fft_coefficient__coeff_2__attr_"angle"  \
# 0                                         103.922087
# 1                                          99.293878
# 2                                         105.809840
# 3                                          99.195454
# 4                                         107.304441
#
#    Zone15_Pressure__augmented_dickey_fuller__attr_"teststat"  \
# 0                                           0.414992
# 1                                           3.125592
# 2                                          -1.049866
# 3                                           0.190631
# 4                                          -1.013413
#
#    Zone15_Pressure__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0  \
# 0                                          41.544038
# 1                                          42.191759
# 2                                         135.024234
# 3                                         109.336323
# 4                                          58.622933
#
#    Zone15_Pressure__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4  \
# 0                                          41.544038
# 1                                          42.191759
# 2                                         135.024234
# 3                                         109.336323
# 4                                          58.622933
#
#    Zone15_Pressure__count_below_mean  ...  \
# 0                              637.0  ...
# 1                              670.0  ...
# 2                              579.0  ...
# 3                              649.0  ...
# 4                              614.0  ...
#
#    Zone31_Pressure__fft_coefficient__coeff_2__attr_"real"  \
# 0                                      -6.422572e+04
# 1                                       1.050872e+06
# 2                                      -8.241194e+05
# 3                                       3.191185e+05
# 4                                      -1.769839e+06
#
#    Zone3_Pressure__fft_coefficient__coeff_2__attr_"angle"  \
# 0                                         110.365035
# 1                                          95.690130
# 2                                         125.073052
# 3                                         122.341734
# 4                                         135.023802
#
#    Zone4_Pressure__fft_coefficient__coeff_2__attr_"angle"  \
# 0                                         110.278247
# 1                                          95.042478
# 2                                         127.395796
# 3                                         121.163053
# 4                                         133.033379
#
#    Zone6_Pressure__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6  \
# 0                                         156.500929
# 1                                         170.289578
# 2                                         131.877713
# 3                                         104.833596
# 4                                          90.345308
#
#    Zone6_Pressure__fft_coefficient__coeff_2__attr_"angle"  \
# 0                                         114.538620
# 1                                         101.596777
# 2                                         121.304061
# 3                                         113.813513
# 4                                         120.139598
#
#    Zone6_Pressure__partial_autocorrelation__lag_2  \
# 0                                       -0.269811
# 1                                       -0.043765
# 2                                       -0.269597
# 3                                       -0.203451
# 4                                       -0.241381
#
#    Zone7_Pressure__augmented_dickey_fuller__attr_"teststat"  \
# 0                                           0.465443
# 1                                           2.991166
# 2                                          -1.148494
# 3                                          -0.118756
# 4                                          -0.864557
#
#    Zone7_Pressure__fft_coefficient__coeff_2__attr_"angle"  \
# 0                                          92.618935
# 1                                          71.918399
# 2                                          86.354413
# 3                                          97.134776
# 4                                          94.354414
#
#    Zone7_Pressure__fft_coefficient__coeff_3__attr_"angle"  target
# 0                                         139.140951            0
# 1                                          47.388674            0
# 2                                         127.533329            0
# 3                                          33.477185            1
# 4                                         133.792957            1
#
# [5 rows x 42 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=seed)

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=seed)
rf_model.fit(X_train, y_train)

y_pred = algorithm.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77      1635
#            1       0.77      0.81      0.79      1670
#
#     accuracy                           0.78      3305
#    macro avg       0.78      0.78      0.78      3305
# weighted avg       0.78      0.78      0.78      3305

# %% [markdown]
# ### TPOT

# %%
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split

tpot = TPOTClassifier(generations=50, population_size=50, n_jobs=-1, verbosity=2)
tpot.fit(X_train, y_train)
# Out:
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=2550, style=ProgressStyle(descrip…

# %%
tpot.score(X_test, y_test)

# %%
tpot.export('tmp/tpot_composite_pipeline.py')
